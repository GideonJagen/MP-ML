# %%
import tifffile
from matplotlib import pyplot as plt
import numpy as np
import glob
import torch

# %%
filepath = r"../data/Spike_LowDensity.tiff"

images = tifffile.imread(filepath, key=range(300, 16000))

# %%
print(images.shape)
# Out:
# (15700, 81, 128)

# %%
plt.imshow(images[1525, :, :], cmap='gray')
